# %% [markdown]
# # Funktioner
#
# - Inparameter
# - return-sats
# - lokala variabler

# %%
def medelvärde(a,b,c,d):
    medel = (a+b+c+d)/4 #lokal variabel, syns ej utanför funktionen
    return medel

print(medelvärde(1,2,3,4))
print(medelvärde(10,20,30,40))
# Out:
# 2.5

# %%
# räkna ord

def räkna_ord(text):
    ord = text.split()
    antal_ord = len(ord)
    return antal_ord

citat = "I stand on the shoulders of giants"
print(f"Antal ord i citatet: {räkna_ord(citat)}")
# Out:
# Antal ord i citatet: 7

# %%
import numpy as np
import matplotlib.pyplot as plt

år = int(input("Antal år efter 1950: "))

def N(t):
    manniskor = 11/(1+3.4*np.exp(-0.03*t))
    return manniskor

print(N(år))

# b) övre gräns?

år = 500

t = np.arange(år)

plt.plot(t, N(t))
plt.ylabel("Antal människor i miljarder")
plt.xlabel("År efter 1950")
plt.title("Modell för population")
plt.grid()
plt.show()


print(f"Övre gräns: {N(5000)} miljarder")
# Out:
# 2.617801412076047
# Övre gräns: 11.0 miljarder

# %%
def f(x):
    return -x**2

print(f(3))
print(f(-3))
# Out:
# -9
# -9

# %% [markdown]
# ## Area av triangel
#
# $$A = b*h/2$$

# %%
def triangelArea(bas, höjd): #Vad man vill ha och vad man behöver för att ta reda på arean
    area = bas*höjd/2
    return area

area1 = triangelArea(2,4)
area2 = triangelArea(10,12)
print(f"Arean på en triangel med bas 2 1.e. och höjd 4 1.e. är {area1} a.e.")
print(f"Arean på en triangel med bas 10 1.e. och höjd 12 1.e. är {area2} a.e.")
# Out:
# Arean på en triangel med bas 2 1.e. och höjd 4 1.e. är 4.0 a.e.
# Arean på en triangel med bas 10 1.e. och höjd 12 1.e. är 60.0 a.e.

# %%
def aritmetisk_summa(a1,n,an):
    sn = (n*(a1+an))/2
    return sn
 
summa = aritmetisk_summa(1,2,100)

print(summa)
# Out:
# 101.0
